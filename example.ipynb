# %%
import matplotlib.pyplot as pl

from utils import *

# %%
filepath='./data/beamlets_CS002C_00_01.png'

# %% [markdown]
# All of the following steps are contained in `lodata.read_png()`:

# %%
lodata = LoData(filepath)  # initiate class

# %%
lodata.open_png()          # read the png into a numpy array

# %%
lodata.mask_png()          # mask all the annotations (also masks a little bit of data)

# %%
lodata.find_nbeams()       # determine how many beams are present (might need tuning on more data)
print("# beams: {}".format(lodata.nbeams))
# Out:
# # beams: 1

# %%
lodata.get_corners()       # specify the corners of data images in the png (hard coded corners)

# %%
lodata.extract_data()      # extract the data into separate numpy arrays for each beam

# %%
pl.imshow(lodata.im)       # original png
pl.show()

# %%
pl.imshow(lodata.data[0,:,:,:])  # extracted & downsampled data array
pl.show()

# ignore clipping message for now
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
